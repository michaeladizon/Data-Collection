# %% [markdown]
# # Getting data directly from a website

# %% [markdown]
# This notebook scrapes data from [CNN News](https://edition.cnn.com/) usine NewsAPI, gathering the contents of news articles published on March 11 and 12, 2021 and saves the details in a json file.

# %% [markdown]
# ### Import necessary libraries

# %%
import requests
import pprint
import json

# %% [markdown]
# ### Set url and parameters

# %%
url = 'https://newsapi.org/v2/everything?'
api_key = '90f6bc83c6214d1ca353346dba8de01e'

# %%
parameters = {
    'domains': 'cnn.com',
    'pageSize': 100,
    'apiKey': api_key,
    'from': '2021-03-11',
    'to': '2021-03-12',
    'language': 'en'
}
response = requests.get(url, params = parameters)
response_json = response.json()

# %%
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Manu Raju and Alex Rogers, CNN',
#                'content': '(CNN)Senate Minority Leader Mitch McConnell is '
#                           'quietly maneuvering to field a slate of GOP Senate '
#                           'candidates in critical battleground states, '
#                           'attempting to avoid a repeat of election cycles a '
#                           'decade … [+10897 chars]',
#                'description': 'Senate Minority Leader Mitch McConnell is '
#                               'quietly maneuvering to field a slate of GOP '
#                               'Senate candidates in critical battleground '
#                               'states, attempting to avoid a repeat of '
#                               'election cycles a decade ago when candidates '
#                               'emerged from primaries only to implode and de…',
#                'publishedAt': '2021-03-12T23:46:41Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'McConnell quietly courts Senate primary candidates '
#                         "'who can win' regardless of Trump ties",
#                'url': 'https://www.cnn.com/2021/03/12/politics/mitch-mcconnell-donald-trump-2022-senate-races/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210213165012-mitch-mcconnell-february-13-2021-02-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': 'Actor, author and activist George Takei tells '
#                               "CNN's Anderson Cooper about the constant "
#                               'presence of anti-Asian hate crimes in the US. '
#                               'Watch "Full Circle" every Monday, Tuesday and '
#                               'Friday at 6p E.T.',
#                'publishedAt': '2021-03-12T23:32:36Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'George Takei on how Trump exacerbated anti-Asian hate',
#                'url': 'https://www.cnn.com/videos/politics/2021/03/12/george-takei-anti-asian-hate-crimes-acfc-sot-vpx.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312182730-mobapp-george-takei-acfc-sot-vpx-super-tease.jpg'},
#               {'author': 'Sonnet Swire, CNN',
#                'content': 'THE POINT -- NOW ON YOUTUBE! \r\n'
#                           'In each episode of his weekly YouTube show, Chris '
#                           'Cillizza will delve a little deeper into the '
#                           'surreal world of politics. Click to subscribe!',
#                'description': 'This week, Biden marked the pandemic '
#                               'anniversary with his first prime-time address '
#                               'as President. He gave an emotional speech after '
#                               'signing a landmark Covid-19 recovery bill into '
#                               'law on Thursday. Meanwhile, more states moved '
#                               'to limit voter access in upcoming e…',
#                'publishedAt': '2021-03-12T23:31:06Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'The week in 13 headlines',
#                'url': 'https://www.cnn.com/2021/03/12/politics/week-in-review-biden-covid-stimulus/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312044046-joe-biden-0312-super-tease.jpg'},
#               {'author': 'Analysis by Lauren Dezenski, CNN',
#                'content': 'THE POINT -- NOW ON YOUTUBE! \r\n'
#                           'In each episode of his weekly YouTube show, Chris '
#                           'Cillizza will delve a little deeper into the '
#                           'surreal world of politics. Click to subscribe!',
#                'description': "As the pandemic's one-year mark came and went, "
#                               'President Joe Biden dangled a major piece of '
#                               'hope in front of the American people: a taste '
#                               'of (nearly) normal on July Fourth, if only we '
#                               'stay the course.',
#                'publishedAt': '2021-03-12T23:30:48Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Biden tees up a hopeful Independence Day',
#                'url': 'https://www.cnn.com/2021/03/12/politics/biden-july-4-coronavirus-cuomo-border/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311182531-01-joe-biden-0210-super-tease.jpg'},
#               {'author': 'Jen Christensen, CNN',
#                'content': '(CNN)You can hug your vaccinated grandpa and stay '
#                           'to play cards with him at his nursing home, even if '
#                           "you haven't been vaccinated, according to new "
#                           'Covid-19 guidance for nursing homes from the '
#                           'Center… [+6191 chars]',
#                'description': 'You can hug your vaccinated grandpa and stay to '
#                               'play cards with him at his nursing home, even '
#                               "if you haven't been vaccinated, according to "
#                               'new Covid-19 guidance for nursing homes from '
#                               'the Centers for Medicare and Medicaid Services.',
#                'publishedAt': '2021-03-12T23:25:32Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'With new nursing home guidelines, card games with '
#                         'grandpa are back, regardless of your vaccination '
#                         'status',
#                'url': 'https://www.cnn.com/2021/03/12/health/new-nursing-home-guidelines-wellness/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/201219175301-03-boy-scouts-nursing-home-hug-booth-super-tease.jpg'},
#               {'author': 'Marianne Garvey, CNN',
#                'content': None,
#                'description': 'Jennifer Lopez and Alex Rodriguez are going '
#                               'their separate ways.',
#                'publishedAt': '2021-03-12T23:17:42Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Jennifer Lopez and Alex Rodriguez split',
#                'url': 'https://www.cnn.com/2021/03/12/entertainment/jennifer-lopez-alex-rodriguez-split/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312164227-01-jennifer-lopez-alex-rodriguez-file-super-tease.jpg'},
#               {'author': 'Opinion by Fred Wertheimer',
#                'content': 'Fred Wertheimer is president of Democracy 21, a '
#                           'nonpartisan, non-profit organization that works to '
#                           'strengthen US democracy and empower citizens in the '
#                           'political process. The opinions expressed here a… '
#                           '[+8230 chars]',
#                'description': 'Fred Wertheimer writes that Republicans used to '
#                               'be proponents of democatic reforms, such as the '
#                               'expansion of voting rights, but they have '
#                               'changed course since the Citizens United court '
#                               "decision -- and now it's incumbent upon "
#                               'Congress to step in.',
#                'publishedAt': '2021-03-12T23:17:24Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'The bitter irony in the GOP trying to curtail voting '
#                         'rights',
#                'url': 'https://www.cnn.com/2021/03/12/opinions/republican-party-irony-voting-rights-wertheimer/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210301153953-03-voting-file-super-tease.jpg'},
#               {'author': 'Curt Devine, Drew Griffin and Zachary Cohen, CNN',
#                'content': '(CNN)Police in Washington, DC, are investigating an '
#                           'allegation that conspiracy theorist Alex Jones '
#                           'threatened to push a pro-Trump political organizer '
#                           'off of an event stage in December, according to p… '
#                           '[+5606 chars]',
#                'description': 'Police in Washington, DC, are investigating an '
#                               'allegation that conspiracy theorist Alex Jones '
#                               'threatened to push a pro-Trump political '
#                               'organizer off of an event stage in December, '
#                               'according to people familiar with the incident.',
#                'publishedAt': '2021-03-12T23:01:58Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Alex Jones allegedly threatened to throw Trump rally '
#                         'organizer off a stage',
#                'url': 'https://www.cnn.com/2021/03/12/politics/alex-jones-police-investigation-invs/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312163200-alex-jones-200418-file-super-tease.jpg'},
#               {'author': 'Konstantin Toropin, CNN',
#                'content': '(CNN)The Norman, Oklahoma, Public Schools District '
#                           'is condemning an announcer who "made racist and '
#                           'hateful comments targeted at our Norman High '
#                           'student athletes" on a livestream of a state '
#                           'basketball… [+2349 chars]',
#                'description': 'The Norman, Oklahoma, Public Schools District '
#                               'is condemning an announcer who "made racist and '
#                               'hateful comments targeted at our Norman High '
#                               'student athletes" on a livestream of a state '
#                               'basketball tournament, a statement from the '
#                               'district superintendent said.',
#                'publishedAt': '2021-03-12T22:56:25Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'An announcer hurled racial insults at a high school '
#                         'basketball team for kneeling during the National '
#                         'Anthem',
#                'url': 'https://www.cnn.com/2021/03/12/us/announcer-racial-insults-high-school-kneeling-anthem/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312172929-ok-basketball-team-insulted-for-kneeling-super-tease.jpg'},
#               {'author': 'Geneva Sands, CNN',
#                'content': None,
#                'description': 'The Biden administration on Friday granted '
#                               'humanitarian protection to Burmese nationals '
#                               'and residents in the United States due to the '
#                               'military coup and violence against civilians in '
#                               'Myanmar.',
#                'publishedAt': '2021-03-12T22:46:56Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Biden administration grants humanitarian protection '
#                         'for Burmese in US',
#                'url': 'https://www.cnn.com/2021/03/12/politics/biden-administration-tps-burmese-nationals/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210301193425-01-dhs-logo-file-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': "Since May 2020, the site of George Floyd's "
#                               'death in Minneapolis has served as a memorial '
#                               "and place for prayer, but now it's surrounded "
#                               "by barricades and increasing violence. CNN's "
#                               'Sara Sidner has more.',
#                'publishedAt': '2021-03-12T22:41:14Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Why George Floyd's memorial site is surrounded by "
#                         'barricades',
#                'url': 'https://www.cnn.com/videos/us/2021/03/12/george-floyd-memorial-site-barricades-violence-sidner-dnt-lead-vpx.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210301174415-01-george-floyd-mural-file-super-tease.jpg'},
#               {'author': 'Alisha Ebrahimji, CNN',
#                'content': '(CNN)When Subhakar Khadka immigrated to California '
#                           'seven years ago, he had his sights set on a simple '
#                           'life with simple goals: Earn a living so that his '
#                           'family in Nepal can join him in the United Stat… '
#                           '[+7537 chars]',
#                'description': 'When Subhakar Khadka immigrated to California '
#                               'seven years ago, he had his sights set on a '
#                               'simple life with simple goals: Earn a living so '
#                               'that his family in Nepal can join him in the '
#                               'United States.',
#                'publishedAt': '2021-03-12T22:37:35Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Two women facing charges for allegedly harassing Uber '
#                         'driver in mask dispute',
#                'url': 'https://www.cnn.com/2021/03/12/business/uber-driver-mask-dispute-california-trnd/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312162603-01-uber-california-mask-altercation-super-tease.jpg'},
#               {'author': 'Jessica Dean, Ali Zaslav and Daniella Diaz, CNN',
#                'content': '(CNN)Senate Democrats will move forward on new gun '
#                           'legislation, promising to bring a bill expanding '
#                           'background checks on all firearm sales to the floor '
#                           'for a vote, despite the uphill climb ahead to g… '
#                           '[+5960 chars]',
#                'description': 'Senate Democrats will move forward on new gun '
#                               'legislation, promising to bring a bill '
#                               'expanding background checks on all firearm '
#                               'sales to the floor for a vote, despite the '
#                               'uphill climb ahead to garner the 60 votes '
#                               'needed for it to pass.',
#                'publishedAt': '2021-03-12T22:32:34Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "'A vote is what we need': Gun safety bill faces "
#                         'uphill climb in Senate',
#                'url': 'https://www.cnn.com/2021/03/12/politics/gun-control-senate-fight/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/191113111541-us-capitol-impeachment-hearing-1113-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': 'As an entire industry gears up for a return to '
#                               "travel, CNN's Richard Quest explores what's "
#                               'being done to make it easier and checks in with '
#                               'the road warriors keeping the travel dream '
#                               'alive.',
#                'publishedAt': '2021-03-12T22:23:39Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Trying travel: Will it ever be easy again?',
#                'url': 'https://www.cnn.com/videos/travel/2021/03/12/business-traveller-pandemic-travel-will-it-get-easier-spc.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312165557-business-traveller-pandemic-travel-will-it-get-easier-spc-00065429-super-tease.png'},
#               {'author': 'Geneva Sands, CNN',
#                'content': '(CNN)Immigration and Customs Enforcement asked for '
#                           'volunteers from the agency to support the federal '
#                           "government's efforts along the US-Mexico border as "
#                           'the Biden administration continues to grapple w… '
#                           '[+877 chars]',
#                'description': 'Immigration and Customs Enforcement asked for '
#                               'volunteers from the agency to support the '
#                               "federal government's efforts along the "
#                               'US-Mexico border as the Biden administration '
#                               'continues to grapple with an influx of migrants '
#                               'at the southwest border.',
#                'publishedAt': '2021-03-12T22:12:47Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'ICE asks for agency volunteers to assist at the '
#                         'US-Mexico border amid surge of migrant children',
#                'url': 'https://www.cnn.com/2021/03/12/politics/ice-agency-volunteers-migrant-children/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210218111150-ice-super-tease.jpg'},
#               {'author': 'Opinion by James Moore',
#                'content': 'James Moore is a political analyst, author and '
#                           'business communications consultant who has been '
#                           'writing and reporting on Texas politics since 1975. '
#                           'He is the founder of Big Bend Strategies and '
#                           'publish… [+6108 chars]',
#                'description': 'Texan James Moore writes that Matthew '
#                               'McConaughey should not run for governor of '
#                               'Texas because he is exactly what the state does '
#                               'not need -- someone with great talent in his '
#                               'chosen profession and no known experience in '
#                               'public office or politics.',
#                'publishedAt': '2021-03-12T22:05:32Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Matthew McConaughey, stay out of Texas politics',
#                'url': 'https://www.cnn.com/2021/03/12/opinions/matthew-mcconaughey-texas-politics-moore/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/190925133113-01-matthew-mcconaughey-texas-file-super-tease.jpg'},
#               {'author': 'By Krystin Arneson',
#                'content': 'Size-inclusive brand Summersalt, which is lauded '
#                           'for both its great fits and sleek shapes, is '
#                           'looking to take over your top drawer with a new '
#                           'intimates collection. And yes, you can bet the fits '
#                           'are h… [+994 chars]',
#                'description': 'Size-inclusive brand Summersalt, which is '
#                               'lauded for both its great fits and sleek '
#                               'shapes, is looking to take over your top drawer '
#                               'with a new underwear collection.',
#                'publishedAt': '2021-03-12T22:01:02Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Size-inclusive label Summersalt just launched '
#                         'intimates',
#                'url': 'https://www.cnn.com/2021/03/12/cnn-underscored/summersalt-underwear-launch/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311101552-summersalt-lead-super-169.jpg'},
#               {'author': 'Marshall Cohen',
#                'content': '(CNN)A federal judge ordered one of the alleged '
#                           'Oath Keepers charged in the Capitol riot to be '
#                           'released on Friday, and questioned the strength of '
#                           'the conspiracy case against him.\r\n'
#                           'Thomas Caldwell, a … [+1220 chars]',
#                'description': 'A federal judge ordered one of the alleged Oath '
#                               'Keepers charged in the Capitol riot to be '
#                               'released on Friday, and questioned the strength '
#                               'of the conspiracy case against him.',
#                'publishedAt': '2021-03-12T21:56:35Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Judge releases alleged Oath Keeper and questions '
#                         'strength of conspiracy case',
#                'url': 'https://www.cnn.com/2021/03/12/politics/oath-keeper-thomas-caldwell-released/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210221090239-capitol-riots-210106-file-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': "After Biden's shutdown of Keystone XL, the next "
#                               'fight over pipelines has shifted to Minnesota, '
#                               'where the Canadian multinational company '
#                               'Enbridge is currently replacing their Line 3 '
#                               "pipeline. CNN's Bill Weir heads to an Enbridge "
#                               'construction site in Northern M…',
#                'publishedAt': '2021-03-12T21:47:48Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'The next Keystone XL fight is here',
#                'url': 'https://www.cnn.com/videos/us/2021/03/12/gothere-enbridgeline3-billweir-dpweekend.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312164317-gothere-enbridgeline3-thumb4-1-super-tease.jpg'},
#               {'author': 'Brian Fung and Alex Marquardt, CNN',
#                'content': 'Washington (CNN)The Biden administration warned '
#                           'Friday that organizations face enormous risks from '
#                           'the recently disclosed Microsoft Exchange '
#                           'vulnerabilities that have affected thousands of '
#                           'private or… [+5448 chars]',
#                'description': 'The Biden administration warned Friday that '
#                               'organizations face enormous risks from the '
#                               'recently disclosed Microsoft Exchange '
#                               'vulnerabilities that have affected thousands of '
#                               'private organizations.',
#                'publishedAt': '2021-03-12T21:47:14Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "White House warns organizations have 'hours, not "
#                         "days' to fix vulnerabilities as Microsoft Exchange "
#                         'attacks increase',
#                'url': 'https://www.cnn.com/2021/03/12/politics/microsoft-solarwinds-biden-administration/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210302224321-microsoft-china-hackers-exchange-file-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': 'President Joe Biden touted his $1.9 trillion '
#                               'Covid-19 stimulus deal while speaking from the '
#                               'White House Rose Garden, saying it "changes the '
#                               'paradigm" for workers in the United States.',
#                'publishedAt': '2021-03-12T21:39:34Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Biden: Covid-19 relief deal puts working people first',
#                'url': 'https://www.cnn.com/videos/politics/2021/03/12/joe-biden-middle-class-coronavirus-relief-deal-sot-nr-vpx.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312150228-03-white-house-covid-relief-event-0312-super-tease.jpg'},
#               {'author': "Sara Ashley O'Brien, CNN Business",
#                'content': '(CNN Business)Elizabeth Holmes, the founder of '
#                           'failed biotech company Theranos, is pregnant -- a '
#                           'new development that could once again delay the '
#                           'start date of her highly-anticipated criminal fraud '
#                           'tr… [+1296 chars]',
#                'description': 'Elizabeth Holmes, the founder of failed biotech '
#                               'company Theranos, is pregnant -- a new '
#                               'development that could once again delay the '
#                               'start date of her highly-anticipated criminal '
#                               'fraud trial.',
#                'publishedAt': '2021-03-12T21:35:17Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Theranos founder Elizabeth Holmes is pregnant, likely '
#                         'delaying her criminal trial',
#                'url': 'https://www.cnn.com/2021/03/12/tech/theranos-elizabeth-holmes-pregnancy/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312113031-elizabeth-holmes-theranos-file-super-tease.jpg'},
#               {'author': 'Dakin Andone, CNN',
#                'content': '(CNN)An Oklahoma death row inmate is set to receive '
#                           'a new trial after a court overturned his conviction '
#                           'based on a US Supreme Court ruling last year that '
#                           'determined a large part of the state is Nativ… '
#                           '[+5154 chars]',
#                'description': 'An Oklahoma death row inmate is set to receive '
#                               'a new trial after a court overturned his '
#                               'conviction based on a US Supreme Court ruling '
#                               'last year that determined a large part of the '
#                               'state is Native American territory for the '
#                               'purposes of federal criminal law.',
#                'publishedAt': '2021-03-12T21:33:26Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "A convicted Oklahoma killer's death sentence was "
#                         'overturned because of a landmark US Supreme Court '
#                         'ruling',
#                'url': 'https://www.cnn.com/2021/03/12/us/shaun-bosse-oklahoma-conviction-overturned/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312101341-file-shaun-bosse-super-tease.jpg'},
#               {'author': 'Julia Jones and Kyung Lah, CNN',
#                'content': '(CNN)Students in the Los Angeles Unified School '
#                           "District, the country's second-largest school "
#                           'district, have been attending digital-only classes '
#                           'for a year now. And for one Los Angeles family, '
#                           'remote… [+4864 chars]',
#                'description': 'Students in the Los Angeles Unified School '
#                               "District, the country's second-largest school "
#                               'district, have been attending digital-only '
#                               'classes for a year now. And for one Los Angeles '
#                               'family, remote learning has taken a toll, not '
#                               'the least of which may be their c…',
#                'publishedAt': '2021-03-12T21:30:09Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'A day in the life of this Los Angeles family shows '
#                         'the challenges of a year of distance learning',
#                'url': 'https://www.cnn.com/2021/03/12/us/los-angeles-schools-distance-learning-family-challenges/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311185012-03-corbin-family-super-tease.jpg'},
#               {'author': 'By Michael Andronico and Jacob Krol, CNN',
#                'content': 'As weve all been adjusting to life-from-home mixed '
#                           'with work-from-home for a year, the importance of '
#                           'calls - audio and video - has reached a new height. '
#                           'And so has the need for a good pair of earbuds… '
#                           '[+29547 chars]',
#                'description': "As we've all been adjusting to life-from-home "
#                               'mixed with work-from-home for a year, the '
#                               'importance of calls ---- audio and video ---- '
#                               'has reached a new height. And so has the need '
#                               'for a good pair of earbuds or headphones to '
#                               'help you concentrate and be heard.',
#                'publishedAt': '2021-03-12T21:25:05Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'The best work from earbuds and headphones',
#                'url': 'https://www.cnn.com/2021/03/12/cnn-underscored/best-work-from-home-earbuds-headphones/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312161419-best-wfh-headphones-lead-super-169.jpg'},
#               {'author': None,
#                'content': None,
#                'description': "In an interview with CNN's Brooke Baldwin, "
#                               'labor and employment attorney Brett Coburn '
#                               "discusses employees' rights as more companies "
#                               'are preparing a return to the workplace.',
#                'publishedAt': '2021-03-12T21:22:17Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Can employers force employees to return to the '
#                         'office?',
#                'url': 'https://www.cnn.com/videos/health/2021/03/12/brett-coburn-intv-employers-employees-work-covid-19-office-vaccine-sot-nr-vpx.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312153913-covid-anniversary-video-thumbnail-2-super-tease.jpg'},
#               {'author': 'Jennifer Hansler, CNN',
#                'content': '(CNN)Trevor Reed, an American jailed in Russia, was '
#                           'transferred without notice to a different '
#                           'pre-detention center last week and his family has '
#                           'not heard from him since, according to the family '
#                           'spoke… [+2551 chars]',
#                'description': 'Trevor Reed, an American jailed in Russia, was '
#                               'transferred without notice to a different '
#                               'pre-detention center last week and his family '
#                               'has not heard from him since, according to the '
#                               'family spokesperson.',
#                'publishedAt': '2021-03-12T21:13:27Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'American being held in Russia has been transferred '
#                         'without notice, family spokesperson says',
#                'url': 'https://www.cnn.com/2021/03/12/politics/trevor-reed-transferred/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200730135514-trevor-reed-ex-marine-sentencing-russia-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': 'Carrie Hawes describes what happened when she '
#                               'was told she was one of the customers at a '
#                               'Virginia clinic who accidentally received an '
#                               'empty Covid-19 shot.',
#                'publishedAt': '2021-03-12T20:55:43Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Woman describes getting empty shot of Covid-19 '
#                         'vaccine',
#                'url': 'https://www.cnn.com/videos/health/2021/03/12/covid-19-vaccine-empty-shot-carrie-hawes-nr-vpx-sot.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312155336-carrie-hawes-brianna-keilar-march-12-2021-super-tease.jpg'},
#               {'author': 'Kevin Liptak and Arlette Saenz, CNN',
#                'content': '(CNN)Bidding farewell to his adopted home state in '
#                           'January, Joe Biden -- then the President-elect -- '
#                           'grew emotional as he boarded his flight to '
#                           'Washington for the inauguration.\r\n'
#                           '"When I die," he said… [+10057 chars]',
#                'description': 'Bidding farewell to his adopted home state in '
#                               'January, Joe Biden -- then the President-elect '
#                               '-- grew emotional as he boarded his flight to '
#                               'Washington for the inauguration.',
#                'publishedAt': '2021-03-12T20:44:39Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Joe Biden just can't quit Delaware -- even as "
#                         'president',
#                'url': 'https://www.cnn.com/2021/03/12/politics/joe-biden-delaware-white-house/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210302111433-biden-nov-7-2020-super-tease.jpg'},
#               {'author': 'Anna Bahney, CNN Business',
#                'content': None,
#                'description': 'The $1.9 trillion stimulus package that '
#                               'President Joe Biden signed into law Thursday '
#                               'includes close to $50 billion in housing '
#                               'assistance to struggling renters, homeowners '
#                               'and people experiencing homelessness.',
#                'publishedAt': '2021-03-12T20:37:52Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Still unable to pay your rent or mortgage? Here's how "
#                         'the latest stimulus plan will help',
#                'url': 'https://www.cnn.com/2021/03/12/success/state-of-housing-stimulus-covid-relief/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210303155419-us-house-for-sale-0121-restricted-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': 'The royal family is synonymous with the UK, but '
#                               'questions of its role and validity have once '
#                               'again been thrust into the spotlight, with '
#                               'strong opinions for and against.',
#                'publishedAt': '2021-03-12T20:32:05Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Opinion: Does the Monarchy still have a place in the '
#                         'UK?',
#                'url': 'https://www.cnn.com/videos/opinions/2021/03/12/royal-family-uk-role-mxb-lon-orig.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312180420-royal-family-thumbnail-1-super-tease.jpg'},
#               {'author': 'Marshall Cohen and Evan Perez, CNN',
#                'content': 'Washington (CNN)The Justice Department is preparing '
#                           'some of the first guilty plea offers for people '
#                           'charged in the Capitol insurrection, as prosecutors '
#                           'grind through massive amounts of evidence, vide… '
#                           '[+5295 chars]',
#                'description': 'The Justice Department is preparing some of the '
#                               'first guilty plea offers for people charged in '
#                               'the Capitol insurrection, as prosecutors grind '
#                               'through massive amounts of evidence, videos and '
#                               'tips against more than 400 possible defendants '
#                               'in an investigation ca…',
#                'publishedAt': '2021-03-12T20:30:19Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Capitol riot prosecutors may charge more than 400 '
#                         "people and plea deals may come 'within a few weeks'",
#                'url': 'https://www.cnn.com/2021/03/12/politics/us-capitol-riot-investigation-plea-deal/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210209105340-107-january-6-capitol-riots-super-tease.jpg'},
#               {'author': 'Tami Luhby, CNN',
#                'content': '(CNN)Affordable Care Act enrollees and those '
#                           'looking for Obamacare coverage can start accessing '
#                           'the stimulus-enhanced premium subsidies on the '
#                           'federal exchange on April 1, the Biden '
#                           'administration an… [+2951 chars]',
#                'description': 'Affordable Care Act enrollees and those looking '
#                               'for Obamacare coverage can start accessing the '
#                               'stimulus-enhanced premium subsidies on the '
#                               'federal exchange on April 1, the Biden '
#                               'administration announced Friday.',
#                'publishedAt': '2021-03-12T20:14:16Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Stimulus-enhanced Affordable Care Act subsidies '
#                         'coming April 1, but the jobless will have to wait '
#                         'longer',
#                'url': 'https://www.cnn.com/2021/03/12/politics/affordable-care-act-subsidies-stimulus/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210212175810-obamacare-sign-file-2015-super-tease.jpg'},
#               {'author': 'Leah Asmelash and Melissa Alonso, CNN',
#                'content': None,
#                'description': 'One Georgetown Law professor has been fired and '
#                               'another placed on administrative leave after '
#                               "one's comments disparaging Black students were "
#                               'recorded via Zoom.',
#                'publishedAt': '2021-03-12T20:12:45Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Georgetown Law fires a professor after she was seen '
#                         'on video complaining about Black students',
#                'url': 'https://www.cnn.com/2021/03/12/us/georgetown-law-black-students-trnd/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311193230-georgetown-law-school-super-tease.jpg'},
#               {'author': 'Christina Jewett, Kaiser Health News',
#                'content': '(CNN)Since the start of the pandemic, the most '
#                           'terrifying task in health care was thought to be '
#                           'when a doctor put a breathing tube down the trachea '
#                           'of a critically ill covid patient.\r\n'
#                           'Those performin… [+10756 chars]',
#                'description': 'Since the start of the pandemic, the most '
#                               'terrifying task in health care was thought to '
#                               'be when a doctor put a breathing tube down the '
#                               'trachea of a critically ill covid patient.',
#                'publishedAt': '2021-03-12T20:10:36Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Cough more hazardous to Covid-19 medical workers than '
#                         'intubation, research suggests',
#                'url': 'https://www.cnn.com/2021/03/12/health/cdc-masks-health-care-workers-khn-partner/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200323114255-3m-n95-mask--stock-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': "CNN's Brianna Keilar rolls the tape on Fox News "
#                               'host Tucker Carlson for his sexist attacks '
#                               'about women serving in the military.',
#                'publishedAt': '2021-03-12T19:54:15Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Keilar blasts Tucker Carlson's sexist military "
#                         'comments',
#                'url': 'https://www.cnn.com/videos/media/2021/03/12/tucker-carlson-women-in-military-fox-news-roll-the-tape-keilar-vpx.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312141737-keilar-super-tease.jpg'},
#               {'author': 'Barbara Starr, Zachary Cohen and Whitney Wild, CNN',
#                'content': None,
#                'description': "Defense Secretary Lloyd Austin's decision to "
#                               'keep nearly 2,300 National Guard troops on '
#                               'Capitol Hill security duty through May 23 came '
#                               'after the secretary decided against an Army '
#                               'recommendation that less than half that number '
#                               'was actually needed to support US…',
#                'publishedAt': '2021-03-12T19:44:26Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Defense Secretary overruled Army recommendation to '
#                         'reduce number of National Guard troops at Capitol',
#                'url': 'https://www.cnn.com/2021/03/12/politics/austin-army-national-guard-capitol/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210122124257-01-lloyd-austin-lead-image-super-tease.jpg'},
#               {'author': 'Brad Parks and Carma Hassan, CNN',
#                'content': None,
#                'description': 'The Minneapolis City Council has unanimously '
#                               'voted to approve a $27 million settlement to '
#                               "George Floyd's estate.",
#                'publishedAt': '2021-03-12T19:33:48Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Minneapolis City Council approves $27 million '
#                         "settlement to George Floyd's estate",
#                'url': 'https://www.cnn.com/2021/03/12/us/george-floyd-minneapolis-settlement/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210301174415-01-george-floyd-mural-file-super-tease.jpg'},
#               {'author': 'David Williams, CNN',
#                'content': None,
#                'description': 'A quick-thinking customer at a Chick-fil-A '
#                               'drive-thru used the door of his truck to help '
#                               'police catch a fleeing suspect.',
#                'publishedAt': '2021-03-12T19:30:13Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "'Hangry' customer helps police stop alleged suspect "
#                         'running through a Chick-fil-A drive-thru',
#                'url': 'https://www.cnn.com/2021/03/12/us/texas-drive-thru-arrest-trnd/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312100413-suspect-stopped-cfa-drive-thru-trnd-super-tease.jpg'},
#               {'author': 'By Chelsea Stone',
#                'content': 'This weekend, youll find a deal on Allswell '
#                           'mattresses, discounted Apple Watch Sport Loop Bands '
#                           'and savings at Sur La Table. All that and more '
#                           'below.\r\n'
#                           'If youre an Apple Watch wearer, chances are you … '
#                           '[+6933 chars]',
#                'description': "This weekend, you'll find a deal on Allswell "
#                               'mattresses, discounted Apple Watch Sport Loop '
#                               'Bands and savings at Sur La Table. All that and '
#                               'more below.',
#                'publishedAt': '2021-03-12T19:20:23Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'The best sales to shop this weekend: Allswell, '
#                         'Homesick, Under Armour and more',
#                'url': 'https://www.cnn.com/2021/03/12/cnn-underscored/best-online-sales-right-now/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311114228-0312dealslead-super-169.jpg'},
#               {'author': 'Analysis by Chris Cillizza, CNN Editor-at-large',
#                'content': None,
#                'description': 'A coordinated call from the majority of New '
#                               "York's Democratic congressional delegation for "
#                               'Andrew Cuomo to resign in the face of sexual '
#                               'harassment and bullying claims as well as '
#                               'questions surrounding nursing home deaths from '
#                               'Covid-19 badly imperils the New Yo…',
#                'publishedAt': '2021-03-12T19:14:07Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Andrew Cuomo's chances of staying in office just went "
#                         '*way* down',
#                'url': 'https://www.cnn.com/2021/03/12/politics/andrew-cuomo-chance-remain-governor/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210302094518-the-point-andrew-cuomo-super-tease.jpg'},
#               {'author': 'Brian Fung, CNN Business',
#                'content': None,
#                'description': 'Google and Microsoft openly sparred as the '
#                               'latter prepared to testify at a Congressional '
#                               "hearing focusing on Big Tech's impact on local "
#                               'news.',
#                'publishedAt': '2021-03-12T18:55:59Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Google and Microsoft are in a public feud',
#                'url': 'https://www.cnn.com/2021/03/12/tech/microsoft-google-clash/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312071535-sundar-pichai-satya-nadella-split-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': "CNN's Andrew McCabe reacts to former acting "
#                               'Defense Secretary Chris Miller, who was in the '
#                               'office during the US Capitol riot, saying that '
#                               'he sees "cause and effect" between former '
#                               "President Donald Trump's speech and the "
#                               'insurrection on January 6th, 2021.',
#                'publishedAt': '2021-03-12T18:54:48Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Trump's last defense secretary blames Trump for "
#                         'Capitol riot',
#                'url': 'https://www.cnn.com/videos/politics/2021/03/12/chris-miller-trump-us-capitol-riot-andrew-mccabe-nr-vpx-sot.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312133111-chris-miller-file-november-13-2020-01-super-tease.jpeg'},
#               {'author': 'Jacqueline Howard, CNN',
#                'content': '(CNN)During the Covid-19 pandemic, there have been '
#                           '"concerning" declines in childhood vaccinations '
#                           'against other infectious diseases, Dr. Rochelle '
#                           'Walensky, director of the US Centers for Disease '
#                           'Con… [+1749 chars]',
# ...
#                               'Oscars not yielding another ratings d…',
#                'publishedAt': '2021-03-12T14:30:05Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Oscar nominations: Once an outsider, Netflix might be '
#                         'the star in a year of streaming',
#                'url': 'https://www.cnn.com/2021/03/12/entertainment/oscar-nominations-preview/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/201214075537-ma-raineys-black-bottom-chadwick-boseman-super-tease.jpg'},
#               {'author': 'Review by Brian Lowry, CNN',
#                'content': '(CNN)Turns out Soleil Moon Frye -- TV\'s "Punky '
#                           'Brewster" -- meticulously documented her formative '
#                           'years, recently wading back through home movies, '
#                           'phone messages and photos and assembling them into '
#                           '"… [+2630 chars]',
#                'description': 'Turns out Soleil Moon Frye -- TV\'s "Punky '
#                               'Brewster" -- meticulously documented her '
#                               'formative years, recently wading back through '
#                               'home movies, phone messages and photos and '
#                               'assembling them into "Kid 90," a documentary '
#                               'that she calls "A true chronological bluep…',
#                'publishedAt': '2021-03-12T14:28:28Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "In 'Kid 90,' Soleil Moon Frye opens a time capsule "
#                         "about being young and famous in the '90s",
#                'url': 'https://www.cnn.com/2021/03/12/entertainment/kid-90-review/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210308124128-kid-90-soleil-moon-frye-super-tease.jpg'},
#               {'author': 'Kristina Sgueglia, CNN',
#                'content': None,
#                'description': 'Nearly one year after the death of Breonna '
#                               'Taylor, the anniversary of which is Saturday, '
#                               'the family and attorney said, "there\'s still '
#                               'not been justice for Breonna."',
#                'publishedAt': '2021-03-12T14:21:58Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Breonna Taylor's mother says her daughter's death and "
#                         "the lack of justice is 'still unbelievable' a year "
#                         'later',
#                'url': 'https://www.cnn.com/2021/03/12/us/breonna-taylor-mother-tamika-palmer-still-no-justice/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312085744-screengrab-tamika-palmer-cnn-0312-super-tease.jpg'},
#               {'author': 'Rob Picheta, CNN',
#                'content': 'London (CNN)The global rollout of the '
#                           'Oxford-AstraZeneca Covid-19 vaccine has encountered '
#                           'another hurdle as a handful of countries paused '
#                           'their use of the shot following reports it could be '
#                           'linked to… [+7183 chars]',
#                'description': 'The global rollout of the Oxford-AstraZeneca '
#                               'Covid-19 vaccine encountered another hurdle '
#                               'after a handful of countries paused their use '
#                               'of the shot, awaiting more information '
#                               'following reports the vaccine could be linked '
#                               'to blood clots, despite no clear eviden…',
#                'publishedAt': '2021-03-12T14:19:35Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "AstraZeneca says 'no evidence' of blood clot risk "
#                         'from vaccine as countries suspend its use',
#                'url': 'https://www.cnn.com/2021/03/12/europe/astrazeneca-vaccine-blood-clot-reports-denmark-reviews-intl/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210307084241-germany-vaccination-super-tease.jpg'},
#               {'author': 'Brett Harman, CNN',
#                'content': None,
#                'description': 'A smiley snake, a snail with a hidden surprise, '
#                               'and decapitated slugs. These are the must-watch '
#                               'videos of the week.',
#                'publishedAt': '2021-03-12T14:13:44Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Must-watch videos of the week',
#                'url': 'https://www.cnn.com/2021/03/12/world/videos-of-the-week-mobile-march-12/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311084409-russia-mandalorian-razor-crest-replica-ship-2-super-tease.jpg'},
#               {'author': 'Kaya Yurieff, CNN Business',
#                'content': 'New York (CNN Business)On the audio-based app '
#                           'Clubhouse, people are gathering in virtual rooms to '
#                           'make whale moaning noises or to participate in '
#                           'silent meditation together. Hundreds of people on '
#                           'the … [+5033 chars]',
#                'description': 'On the audio-based app Clubhouse, people are '
#                               'gathering in virtual rooms to make whale '
#                               'moaning noises or to participate in silent '
#                               'meditation together. Hundreds of people on the '
#                               'popular gaming platform Discord started a '
#                               'server where they just send each other th…',
#                'publishedAt': '2021-03-12T13:51:00Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'How a year of living almost exclusively online made '
#                         'the internet weird again',
#                'url': 'https://www.cnn.com/2021/03/12/tech/internet-boredom-pandemic/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311131749-clubhouse-twitter-social-media-apps---stock-super-tease.jpg'},
#               {'author': 'By Eoin McSweeney, CNN',
#                'content': 'The lavender clogs can be customized with colorful '
#                           'shoe pins called "Jibbitz charms" and come with '
#                           "white socks from Drew House, Bieber's own clothing "
#                           'brand. Bieber and Crocs are "grabbing the world b… '
#                           '[+1383 chars]',
#                'description': 'Justin Bieber has teamed up with Crocs for the '
#                               'second time, after their first collaboration in '
#                               'October overwhelmed the comfort footwear '
#                               "brand's website and helped fuel record sales.",
#                'publishedAt': '2021-03-12T13:45:45Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Justin Bieber and Crocs are collaborating again, '
#                         'pairing clogs and socks',
#                'url': 'https://www.cnn.com/style/article/justin-bieber-crocs-scli-intl/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312095558-01-crocs-justin-bieber-classic-clog-2-super-tease.jpg'},
#               {'author': 'Selina Wang and Charles Riley, CNN Business',
#                'content': None,
#                'description': 'Simon Hu has resigned as chief executive '
#                               'officer of Ant Group, months after the company '
#                               'was forced to pull its IPO amid a crackdown by '
#                               'Chinese regulators.',
#                'publishedAt': '2021-03-12T13:40:09Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Simon Hu resigns as Ant Group CEO',
#                'url': 'https://www.cnn.com/2021/03/12/tech/ant-group-ceo-simon-hu/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312031622-simon-hu-alibaba-file-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': "Rep. Tim Ryan (D-OH) talks to CNN's John Berman "
#                               "about President Joe Biden's first prime-time "
#                               'address, culture wars, and getting through to '
#                               'Republican members of Congress.',
#                'publishedAt': '2021-03-12T13:38:11Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "Hear lawmaker's emotional plea to GOP members on "
#                         "Biden's relief bill",
#                'url': 'https://www.cnn.com/videos/politics/2021/03/12/tim-ryan-relief-bill-joe-biden-deficit-newday-vpx.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312081121-tim-ryan-0312-super-tease.jpg'},
#               {'author': 'Julia Horowitz, CNN Business',
#                'content': 'A version of this story first appeared in CNN '
#                           "Business' Before the Bell newsletter. Not a "
#                           'subscriber? You can sign up right here.\r\n'
#                           'London (CNN Business)Wall Street threw a party as '
#                           'President Joe Bide… [+6061 chars]',
#                'description': 'Wall Street threw a party as President Joe '
#                               'Biden signed his sweeping $1.9 trillion '
#                               'stimulus package into law, giving investors '
#                               'confidence in their projections for a surge of '
#                               'economic activity once the threat of the '
#                               'pandemic recedes.',
#                'publishedAt': '2021-03-12T13:29:18Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Why stocks could get a boost from $1,400 stimulus '
#                         'checks',
#                'url': 'https://www.cnn.com/2021/03/12/investing/premarket-stocks-trading/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312072322-01-nyse-030921-super-tease.jpg'},
#               {'author': 'Mallika Kallingal, CNN',
#                'content': None,
#                'description': 'NASA is naming landmarks and geological '
#                               'features on Mars in the Navajo language.',
#                'publishedAt': '2021-03-12T13:23:42Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'NASA is naming the rocks and soil on Mars in the '
#                         'Navajo language',
#                'url': 'https://www.cnn.com/2021/03/12/us/nasa-perseverance-mars-navajo-scn-trnd/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312095043-02-nasa-mars-perseverance-navajo-super-tease.jpg'},
#               {'author': None,
#                'content': None,
#                'description': "CNN's Richard Quest reports on how New York "
#                               "City's Broadway is faring over a year into the "
#                               'coronavirus pandemic.',
#                'publishedAt': '2021-03-12T13:18:39Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Broadway was booming. Then Covid-19 took center stage',
#                'url': 'https://www.cnn.com/videos/business/2021/03/12/coronavirus-broadway-jobs-new-york-city-quest-ron-ldn-vpx.cnn',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312130410-coronavirus-broadway-jobs-new-york-city-quest-ron-ldn-vpx-00003112-super-tease.png'},
#               {'author': 'Christina Zdanowicz and Janine Mack, CNN\n'
#                          'Video by Jeff Kopp, CNN',
#                'content': None,
#                'description': "A granddaughter came to her grandmother's "
#                               'apartment bearing a unique gift -- it was a '
#                               'prescription for a hug.',
#                'publishedAt': '2021-03-12T12:48:18Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Grandparents are getting to hug their grandkids for '
#                         'the first time after getting vaccinated',
#                'url': 'https://www.cnn.com/2021/03/12/us/grandparents-hug-grandkids-covid-vaccine-trnd/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210311181725-vaccinated-first-hugs-split-super-tease.jpg'},
#               {'author': 'Toyin Owoseje, CNN',
#                'content': None,
#                'description': 'Sharon Osbourne has issued a public apology to '
#                               'the Black community after facing controversy '
#                               'over her impassioned defense of Piers Morgan on '
#                               'panel show "The Talk".',
#                'publishedAt': '2021-03-12T12:39:42Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Sharon Osbourne apologizes for supporting Piers '
#                         'Morgan in Meghan row',
#                'url': 'https://www.cnn.com/2021/03/12/entertainment/sharon-osbourne-apologizes-intl-scli-gbr/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210312044754-01-sharon-osbourne-the-talk-super-tease.jpg'},
#               {'author': 'Opinion by Marianne Schnall',
#                'content': 'Marianne Schnall is a journalist and the author of '
#                           '"What Will It Take to Make a Woman President? '
#                           'Conversations About Women, Leadership and Power" '
#                           'and the founder of Feminist.com and What Will It '
#                           'Take… [+35222 chars]',
#                'description': "For Women's History Month, Marianne Schnall "
#                               'asked a diverse group of global women leaders '
#                               'to share their views on this year of the '
#                               'coronavirus pandemic and its effects on women '
#                               'and girls. Contributors -- including Tarana '
#                               'Burke, Melinda Gates, Reshma Saujani a…',
#                'publishedAt': '2021-03-12T12:34:46Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Women have taken a staggering Covid hit. Now they '
#                         'offer the best hopes for the future',
#                'url': 'https://www.cnn.com/2021/03/12/opinions/one-year-of-covid-19-pandemic-womens-history-month-schnall/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210309155605-02-international-womens-day-spain-super-tease.jpg'},
#               {'author': 'Ivana Kottasová, CNN',
#                'content': 'A version of this story appeared in the March 12 '
#                           "edition of CNN's Coronavirus: Fact vs. Fiction "
#                           'newsletter. Sign up here to receive the '
#                           'need-to-know headlines every weekday.\r\n'
#                           ' (CNN)US President Joe B… [+7699 chars]',
#                'description': None,
#                'publishedAt': '2021-03-12T12:29:20Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': "'I need every American to do their part,' says Biden, "
#                         'targeting the end of the pandemic',
#                'url': 'https://www.cnn.com/2021/03/12/world/coronavirus-newsletter-03-12-21-int/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200130165125-corona-virus-cdc-image-super-tease.jpg'}],
#  'status': 'ok',
#  'totalResults': 339}

# %% [markdown]
# ### Extract needed data from the response

# %%
articles = response_json['articles']
articles_json = []

for i in range(0, len(articles)):
    link = articles[i]['url']
    date = articles[i]['publishedAt']
    title = articles[i]['title']
    author = articles[i]['author']
    content = articles[i]['content']
    
    articles_json.append({
        'link': link,
        'date': date,
        'title': title,
        'author': author,
        'content': content
    })

# %%
pprint.pprint(articles_json)
# Out:
# [{'author': 'Manu Raju and Alex Rogers, CNN',
#   'content': '(CNN)Senate Minority Leader Mitch McConnell is quietly '
#              'maneuvering to field a slate of GOP Senate candidates in '
#              'critical battleground states, attempting to avoid a repeat of '
#              'election cycles a decade … [+10897 chars]',
#   'date': '2021-03-12T23:46:41Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/mitch-mcconnell-donald-trump-2022-senate-races/index.html',
#   'title': "McConnell quietly courts Senate primary candidates 'who can win' "
#            'regardless of Trump ties'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T23:32:36Z',
#   'link': 'https://www.cnn.com/videos/politics/2021/03/12/george-takei-anti-asian-hate-crimes-acfc-sot-vpx.cnn',
#   'title': 'George Takei on how Trump exacerbated anti-Asian hate'},
#  {'author': 'Sonnet Swire, CNN',
#   'content': 'THE POINT -- NOW ON YOUTUBE! \r\n'
#              'In each episode of his weekly YouTube show, Chris Cillizza will '
#              'delve a little deeper into the surreal world of politics. Click '
#              'to subscribe!',
#   'date': '2021-03-12T23:31:06Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/week-in-review-biden-covid-stimulus/index.html',
#   'title': 'The week in 13 headlines'},
#  {'author': 'Analysis by Lauren Dezenski, CNN',
#   'content': 'THE POINT -- NOW ON YOUTUBE! \r\n'
#              'In each episode of his weekly YouTube show, Chris Cillizza will '
#              'delve a little deeper into the surreal world of politics. Click '
#              'to subscribe!',
#   'date': '2021-03-12T23:30:48Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/biden-july-4-coronavirus-cuomo-border/index.html',
#   'title': 'Biden tees up a hopeful Independence Day'},
#  {'author': 'Jen Christensen, CNN',
#   'content': '(CNN)You can hug your vaccinated grandpa and stay to play cards '
#              "with him at his nursing home, even if you haven't been "
#              'vaccinated, according to new Covid-19 guidance for nursing homes '
#              'from the Center… [+6191 chars]',
#   'date': '2021-03-12T23:25:32Z',
#   'link': 'https://www.cnn.com/2021/03/12/health/new-nursing-home-guidelines-wellness/index.html',
#   'title': 'With new nursing home guidelines, card games with grandpa are '
#            'back, regardless of your vaccination status'},
#  {'author': 'Marianne Garvey, CNN',
#   'content': None,
#   'date': '2021-03-12T23:17:42Z',
#   'link': 'https://www.cnn.com/2021/03/12/entertainment/jennifer-lopez-alex-rodriguez-split/index.html',
#   'title': 'Jennifer Lopez and Alex Rodriguez split'},
#  {'author': 'Opinion by Fred Wertheimer',
#   'content': 'Fred Wertheimer is president of Democracy 21, a nonpartisan, '
#              'non-profit organization that works to strengthen US democracy '
#              'and empower citizens in the political process. The opinions '
#              'expressed here a… [+8230 chars]',
#   'date': '2021-03-12T23:17:24Z',
#   'link': 'https://www.cnn.com/2021/03/12/opinions/republican-party-irony-voting-rights-wertheimer/index.html',
#   'title': 'The bitter irony in the GOP trying to curtail voting rights'},
#  {'author': 'Curt Devine, Drew Griffin and Zachary Cohen, CNN',
#   'content': '(CNN)Police in Washington, DC, are investigating an allegation '
#              'that conspiracy theorist Alex Jones threatened to push a '
#              'pro-Trump political organizer off of an event stage in December, '
#              'according to p… [+5606 chars]',
#   'date': '2021-03-12T23:01:58Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/alex-jones-police-investigation-invs/index.html',
#   'title': 'Alex Jones allegedly threatened to throw Trump rally organizer off '
#            'a stage'},
#  {'author': 'Konstantin Toropin, CNN',
#   'content': '(CNN)The Norman, Oklahoma, Public Schools District is condemning '
#              'an announcer who "made racist and hateful comments targeted at '
#              'our Norman High student athletes" on a livestream of a state '
#              'basketball… [+2349 chars]',
#   'date': '2021-03-12T22:56:25Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/announcer-racial-insults-high-school-kneeling-anthem/index.html',
#   'title': 'An announcer hurled racial insults at a high school basketball '
#            'team for kneeling during the National Anthem'},
#  {'author': 'Geneva Sands, CNN',
#   'content': None,
#   'date': '2021-03-12T22:46:56Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/biden-administration-tps-burmese-nationals/index.html',
#   'title': 'Biden administration grants humanitarian protection for Burmese in '
#            'US'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T22:41:14Z',
#   'link': 'https://www.cnn.com/videos/us/2021/03/12/george-floyd-memorial-site-barricades-violence-sidner-dnt-lead-vpx.cnn',
#   'title': "Why George Floyd's memorial site is surrounded by barricades"},
#  {'author': 'Alisha Ebrahimji, CNN',
#   'content': '(CNN)When Subhakar Khadka immigrated to California seven years '
#              'ago, he had his sights set on a simple life with simple goals: '
#              'Earn a living so that his family in Nepal can join him in the '
#              'United Stat… [+7537 chars]',
#   'date': '2021-03-12T22:37:35Z',
#   'link': 'https://www.cnn.com/2021/03/12/business/uber-driver-mask-dispute-california-trnd/index.html',
#   'title': 'Two women facing charges for allegedly harassing Uber driver in '
#            'mask dispute'},
#  {'author': 'Jessica Dean, Ali Zaslav and Daniella Diaz, CNN',
#   'content': '(CNN)Senate Democrats will move forward on new gun legislation, '
#              'promising to bring a bill expanding background checks on all '
#              'firearm sales to the floor for a vote, despite the uphill climb '
#              'ahead to g… [+5960 chars]',
#   'date': '2021-03-12T22:32:34Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/gun-control-senate-fight/index.html',
#   'title': "'A vote is what we need': Gun safety bill faces uphill climb in "
#            'Senate'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T22:23:39Z',
#   'link': 'https://www.cnn.com/videos/travel/2021/03/12/business-traveller-pandemic-travel-will-it-get-easier-spc.cnn',
#   'title': 'Trying travel: Will it ever be easy again?'},
#  {'author': 'Geneva Sands, CNN',
#   'content': '(CNN)Immigration and Customs Enforcement asked for volunteers '
#              "from the agency to support the federal government's efforts "
#              'along the US-Mexico border as the Biden administration continues '
#              'to grapple w… [+877 chars]',
#   'date': '2021-03-12T22:12:47Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/ice-agency-volunteers-migrant-children/index.html',
#   'title': 'ICE asks for agency volunteers to assist at the US-Mexico border '
#            'amid surge of migrant children'},
#  {'author': 'Opinion by James Moore',
#   'content': 'James Moore is a political analyst, author and business '
#              'communications consultant who has been writing and reporting on '
#              'Texas politics since 1975. He is the founder of Big Bend '
#              'Strategies and publish… [+6108 chars]',
#   'date': '2021-03-12T22:05:32Z',
#   'link': 'https://www.cnn.com/2021/03/12/opinions/matthew-mcconaughey-texas-politics-moore/index.html',
#   'title': 'Matthew McConaughey, stay out of Texas politics'},
#  {'author': 'By Krystin Arneson',
#   'content': 'Size-inclusive brand Summersalt, which is lauded for both its '
#              'great fits and sleek shapes, is looking to take over your top '
#              'drawer with a new intimates collection. And yes, you can bet the '
#              'fits are h… [+994 chars]',
#   'date': '2021-03-12T22:01:02Z',
#   'link': 'https://www.cnn.com/2021/03/12/cnn-underscored/summersalt-underwear-launch/index.html',
#   'title': 'Size-inclusive label Summersalt just launched intimates'},
#  {'author': 'Marshall Cohen',
#   'content': '(CNN)A federal judge ordered one of the alleged Oath Keepers '
#              'charged in the Capitol riot to be released on Friday, and '
#              'questioned the strength of the conspiracy case against him.\r\n'
#              'Thomas Caldwell, a … [+1220 chars]',
#   'date': '2021-03-12T21:56:35Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/oath-keeper-thomas-caldwell-released/index.html',
#   'title': 'Judge releases alleged Oath Keeper and questions strength of '
#            'conspiracy case'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T21:47:48Z',
#   'link': 'https://www.cnn.com/videos/us/2021/03/12/gothere-enbridgeline3-billweir-dpweekend.cnn',
#   'title': 'The next Keystone XL fight is here'},
#  {'author': 'Brian Fung and Alex Marquardt, CNN',
#   'content': 'Washington (CNN)The Biden administration warned Friday that '
#              'organizations face enormous risks from the recently disclosed '
#              'Microsoft Exchange vulnerabilities that have affected thousands '
#              'of private or… [+5448 chars]',
#   'date': '2021-03-12T21:47:14Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/microsoft-solarwinds-biden-administration/index.html',
#   'title': "White House warns organizations have 'hours, not days' to fix "
#            'vulnerabilities as Microsoft Exchange attacks increase'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T21:39:34Z',
#   'link': 'https://www.cnn.com/videos/politics/2021/03/12/joe-biden-middle-class-coronavirus-relief-deal-sot-nr-vpx.cnn',
#   'title': 'Biden: Covid-19 relief deal puts working people first'},
#  {'author': "Sara Ashley O'Brien, CNN Business",
#   'content': '(CNN Business)Elizabeth Holmes, the founder of failed biotech '
#              'company Theranos, is pregnant -- a new development that could '
#              'once again delay the start date of her highly-anticipated '
#              'criminal fraud tr… [+1296 chars]',
#   'date': '2021-03-12T21:35:17Z',
#   'link': 'https://www.cnn.com/2021/03/12/tech/theranos-elizabeth-holmes-pregnancy/index.html',
#   'title': 'Theranos founder Elizabeth Holmes is pregnant, likely delaying her '
#            'criminal trial'},
#  {'author': 'Dakin Andone, CNN',
#   'content': '(CNN)An Oklahoma death row inmate is set to receive a new trial '
#              'after a court overturned his conviction based on a US Supreme '
#              'Court ruling last year that determined a large part of the state '
#              'is Nativ… [+5154 chars]',
#   'date': '2021-03-12T21:33:26Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/shaun-bosse-oklahoma-conviction-overturned/index.html',
#   'title': "A convicted Oklahoma killer's death sentence was overturned "
#            'because of a landmark US Supreme Court ruling'},
#  {'author': 'Julia Jones and Kyung Lah, CNN',
#   'content': '(CNN)Students in the Los Angeles Unified School District, the '
#              "country's second-largest school district, have been attending "
#              'digital-only classes for a year now. And for one Los Angeles '
#              'family, remote… [+4864 chars]',
#   'date': '2021-03-12T21:30:09Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/los-angeles-schools-distance-learning-family-challenges/index.html',
#   'title': 'A day in the life of this Los Angeles family shows the challenges '
#            'of a year of distance learning'},
#  {'author': 'By Michael Andronico and Jacob Krol, CNN',
#   'content': 'As weve all been adjusting to life-from-home mixed with '
#              'work-from-home for a year, the importance of calls - audio and '
#              'video - has reached a new height. And so has the need for a good '
#              'pair of earbuds… [+29547 chars]',
#   'date': '2021-03-12T21:25:05Z',
#   'link': 'https://www.cnn.com/2021/03/12/cnn-underscored/best-work-from-home-earbuds-headphones/index.html',
#   'title': 'The best work from earbuds and headphones'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T21:22:17Z',
#   'link': 'https://www.cnn.com/videos/health/2021/03/12/brett-coburn-intv-employers-employees-work-covid-19-office-vaccine-sot-nr-vpx.cnn',
#   'title': 'Can employers force employees to return to the office?'},
#  {'author': 'Jennifer Hansler, CNN',
#   'content': '(CNN)Trevor Reed, an American jailed in Russia, was transferred '
#              'without notice to a different pre-detention center last week and '
#              'his family has not heard from him since, according to the family '
#              'spoke… [+2551 chars]',
#   'date': '2021-03-12T21:13:27Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/trevor-reed-transferred/index.html',
#   'title': 'American being held in Russia has been transferred without notice, '
#            'family spokesperson says'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T20:55:43Z',
#   'link': 'https://www.cnn.com/videos/health/2021/03/12/covid-19-vaccine-empty-shot-carrie-hawes-nr-vpx-sot.cnn',
#   'title': 'Woman describes getting empty shot of Covid-19 vaccine'},
#  {'author': 'Kevin Liptak and Arlette Saenz, CNN',
#   'content': '(CNN)Bidding farewell to his adopted home state in January, Joe '
#              'Biden -- then the President-elect -- grew emotional as he '
#              'boarded his flight to Washington for the inauguration.\r\n'
#              '"When I die," he said… [+10057 chars]',
#   'date': '2021-03-12T20:44:39Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/joe-biden-delaware-white-house/index.html',
#   'title': "Joe Biden just can't quit Delaware -- even as president"},
#  {'author': 'Anna Bahney, CNN Business',
#   'content': None,
#   'date': '2021-03-12T20:37:52Z',
#   'link': 'https://www.cnn.com/2021/03/12/success/state-of-housing-stimulus-covid-relief/index.html',
#   'title': "Still unable to pay your rent or mortgage? Here's how the latest "
#            'stimulus plan will help'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T20:32:05Z',
#   'link': 'https://www.cnn.com/videos/opinions/2021/03/12/royal-family-uk-role-mxb-lon-orig.cnn',
#   'title': 'Opinion: Does the Monarchy still have a place in the UK?'},
#  {'author': 'Marshall Cohen and Evan Perez, CNN',
#   'content': 'Washington (CNN)The Justice Department is preparing some of the '
#              'first guilty plea offers for people charged in the Capitol '
#              'insurrection, as prosecutors grind through massive amounts of '
#              'evidence, vide… [+5295 chars]',
#   'date': '2021-03-12T20:30:19Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/us-capitol-riot-investigation-plea-deal/index.html',
#   'title': 'Capitol riot prosecutors may charge more than 400 people and plea '
#            "deals may come 'within a few weeks'"},
#  {'author': 'Tami Luhby, CNN',
#   'content': '(CNN)Affordable Care Act enrollees and those looking for '
#              'Obamacare coverage can start accessing the stimulus-enhanced '
#              'premium subsidies on the federal exchange on April 1, the Biden '
#              'administration an… [+2951 chars]',
#   'date': '2021-03-12T20:14:16Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/affordable-care-act-subsidies-stimulus/index.html',
#   'title': 'Stimulus-enhanced Affordable Care Act subsidies coming April 1, '
#            'but the jobless will have to wait longer'},
#  {'author': 'Leah Asmelash and Melissa Alonso, CNN',
#   'content': None,
#   'date': '2021-03-12T20:12:45Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/georgetown-law-black-students-trnd/index.html',
#   'title': 'Georgetown Law fires a professor after she was seen on video '
#            'complaining about Black students'},
#  {'author': 'Christina Jewett, Kaiser Health News',
#   'content': '(CNN)Since the start of the pandemic, the most terrifying task '
#              'in health care was thought to be when a doctor put a breathing '
#              'tube down the trachea of a critically ill covid patient.\r\n'
#              'Those performin… [+10756 chars]',
#   'date': '2021-03-12T20:10:36Z',
#   'link': 'https://www.cnn.com/2021/03/12/health/cdc-masks-health-care-workers-khn-partner/index.html',
#   'title': 'Cough more hazardous to Covid-19 medical workers than intubation, '
#            'research suggests'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T19:54:15Z',
#   'link': 'https://www.cnn.com/videos/media/2021/03/12/tucker-carlson-women-in-military-fox-news-roll-the-tape-keilar-vpx.cnn',
#   'title': "Keilar blasts Tucker Carlson's sexist military comments"},
#  {'author': 'Barbara Starr, Zachary Cohen and Whitney Wild, CNN',
#   'content': None,
#   'date': '2021-03-12T19:44:26Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/austin-army-national-guard-capitol/index.html',
#   'title': 'Defense Secretary overruled Army recommendation to reduce number '
#            'of National Guard troops at Capitol'},
#  {'author': 'Brad Parks and Carma Hassan, CNN',
#   'content': None,
#   'date': '2021-03-12T19:33:48Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/george-floyd-minneapolis-settlement/index.html',
#   'title': 'Minneapolis City Council approves $27 million settlement to George '
#            "Floyd's estate"},
#  {'author': 'David Williams, CNN',
#   'content': None,
#   'date': '2021-03-12T19:30:13Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/texas-drive-thru-arrest-trnd/index.html',
#   'title': "'Hangry' customer helps police stop alleged suspect running "
#            'through a Chick-fil-A drive-thru'},
#  {'author': 'By Chelsea Stone',
#   'content': 'This weekend, youll find a deal on Allswell mattresses, '
#              'discounted Apple Watch Sport Loop Bands and savings at Sur La '
#              'Table. All that and more below.\r\n'
#              'If youre an Apple Watch wearer, chances are you … [+6933 chars]',
#   'date': '2021-03-12T19:20:23Z',
#   'link': 'https://www.cnn.com/2021/03/12/cnn-underscored/best-online-sales-right-now/index.html',
#   'title': 'The best sales to shop this weekend: Allswell, Homesick, Under '
#            'Armour and more'},
#  {'author': 'Analysis by Chris Cillizza, CNN Editor-at-large',
#   'content': None,
#   'date': '2021-03-12T19:14:07Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/andrew-cuomo-chance-remain-governor/index.html',
#   'title': "Andrew Cuomo's chances of staying in office just went *way* down"},
#  {'author': 'Brian Fung, CNN Business',
#   'content': None,
#   'date': '2021-03-12T18:55:59Z',
#   'link': 'https://www.cnn.com/2021/03/12/tech/microsoft-google-clash/index.html',
#   'title': 'Google and Microsoft are in a public feud'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T18:54:48Z',
#   'link': 'https://www.cnn.com/videos/politics/2021/03/12/chris-miller-trump-us-capitol-riot-andrew-mccabe-nr-vpx-sot.cnn',
#   'title': "Trump's last defense secretary blames Trump for Capitol riot"},
#  {'author': 'Jacqueline Howard, CNN',
#   'content': '(CNN)During the Covid-19 pandemic, there have been "concerning" '
#              'declines in childhood vaccinations against other infectious '
#              'diseases, Dr. Rochelle Walensky, director of the US Centers for '
#              'Disease Con… [+1749 chars]',
#   'date': '2021-03-12T18:54:32Z',
#   'link': 'https://www.cnn.com/2021/03/12/health/childhood-vaccines-decline-cdc-wellness-bn/index.html',
#   'title': "Childhood vaccinations see 'substantial' and 'historic' declines "
#            'amid Covid-19 pandemic, CDC director warns'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T18:48:11Z',
#   'link': 'https://www.cnn.com/videos/politics/2021/03/12/jeff-flake-republican-party-trump-era-voting-laws-ip-vpx.cnn',
#   'title': "Jeff Flake: GOP should 'go back to traditional conservatism'"},
#  {'author': 'Jacqueline Howard, CNN',
#   'content': '(CNN)The US Centers for Disease Control and Prevention on Friday '
#              'updated its guidance for childcare programs during the pandemic, '
#              'emphasizing the importance of mask-wearing for everyone 2 years '
#              'of ag… [+4251 chars]',
#   'date': '2021-03-12T18:21:29Z',
#   'link': 'https://www.cnn.com/2021/03/12/health/covid-19-guidance-childcare-programs-cdc-wellness-bn/index.html',
#   'title': 'CDC updates its Covid-19 guidance for childcare programs'},
#  {'author': 'Daniel Dale',
#   'content': 'Washington (CNN)Last weekend, a prominent Republican senator, '
#              'Ted Cruz of Texas, and the second-ranking Democratic senator, '
#              'Dick Durbin of Illinois, had an argument on the Senate floor '
#              'about whether … [+6346 chars]',
#   'date': '2021-03-12T18:18:17Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/fact-check-cruz-durbin-undocumented-relief-checks-rescue-plan/index.html',
#   'title': 'Fact check: No, not all undocumented immigrants will get relief '
#            'checks. Yes, some of them probably will'},
#  {'author': 'Maegan Vazquez, CNN',
#   'content': "Washington (CNN)The White House's coronavirus response team on "
#              'Friday outlined the different ways the federal government will '
#              "be working to implement President Joe Biden's ambitious goals "
#              'unveiled du… [+3674 chars]',
#   'date': '2021-03-12T18:14:45Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/coronavirus-response-team-goals-biden-administration/index.html',
#   'title': "Biden's coronavirus team outlines efforts to meet ambitious new "
#            'goals'},
#  {'author': 'Paul R. La Monica, CNN Business',
#   'content': None,
#   'date': '2021-03-12T18:14:23Z',
#   'link': 'https://www.cnn.com/2021/03/12/investing/diversification-stocks-investing/index.html',
#   'title': "Stocks have been wild lately. Here's how to protect your "
#            'portfolio'},
#  {'author': 'Opinion by Holly Thomas',
#   'content': 'Holly Thomas is a writer and editor based in London. She tweets '
#              '@HolstaT. The opinions expressed in this commentary are solely '
#              'those of the author. View more opinion articles on CNN. This '
#              'piece has b… [+7450 chars]',
#   'date': '2021-03-12T18:12:59Z',
#   'link': 'https://www.cnn.com/2021/03/12/opinions/what-sarah-everard-case-shows-women-and-men-thomas/index.html',
#   'title': "Sarah Everard's case reminds women of what they already knew: "
#            "They're never safe"},
#  {'author': 'Ryan Nobles and Brian Fung CNN Business',
#   'content': None,
#   'date': '2021-03-12T18:11:44Z',
#   'link': 'https://www.cnn.com/2021/03/12/tech/bezos-sanders-senate-budget-testify/index.html',
#   'title': 'Sanders invites Bezos to testify before Senate Budget Committee'},
#  {'author': 'Matt Egan, CNN Business',
#   'content': 'The US economy is going to once again become the global '
#              'locomotive. And it will help pull the rest of the world out of '
#              'this Covid crisis."\r\n'
#              '," said Gregory Daco, chief US economist at Oxford Economics',
#   'date': '2021-03-12T17:54:42Z',
#   'link': 'https://www.cnn.com/2021/03/12/economy/stimulus-economy-biden-china/index.html',
#   'title': "After Biden stimulus, US economic growth could rival China's for "
#            'the first time in decades'},
#  {'author': 'Toyin Owoseje, CNN',
#   'content': None,
#   'date': '2021-03-12T17:53:44Z',
#   'link': 'https://edition.cnn.com/2021/03/12/tennis/andy-murray-fourth-child-scli-intl-gbr-spt/index.html',
#   'title': 'Andy Murray pulls out of Dubai Open after arrival of fourth child'},
#  {'author': 'Jason Kurtz, CNN',
#   'content': None,
#   'date': '2021-03-12T17:52:11Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/ncaa-march-madness-2021-bracket-tournament-spt-trnd/index.html',
#   'title': "Here's how to fill out your March Madness bracket"},
#  {'author': 'Salma Abdelaziz, CNN',
#   'content': None,
#   'date': '2021-03-12T17:47:39Z',
#   'link': 'https://www.cnn.com/2021/03/12/uk/meghan-race-britain-gbr-intl/index.html',
#   'title': 'After Meghan said racism drove her out of the UK, Black Britons '
#            "ask: 'Are we still here in 2021?'"},
#  {'author': 'Jennifer Hansler, CNN',
#   'content': '(CNN)The US State Department on Friday designated a senior '
#              "official to lead the agency's response to the invisible attacks "
#              'against diplomats and US personnel that have left dozens '
#              'suffering from debi… [+3981 chars]',
#   'date': '2021-03-12T17:47:11Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/state-department-havana-syndrome-coordinator/index.html',
#   'title': 'State Department names senior official to lead response to '
#            "mysterious 'Havana syndrome' attacks"},
#  {'author': 'Harmeet Kaur, CNN',
#   'content': '(CNN)Good news for those living in the Aloha State: Hawaiians '
#              'have the highest life expectancy in the nation, according to '
#              'newly released data by the Centers for Disease Control and '
#              'Prevention.\r\n'
#              'Rese… [+2103 chars]',
#   'date': '2021-03-12T17:38:32Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/life-expectancy-state-rankings-wellness-trnd/index.html',
#   'title': 'Here are the states where you can expect to live the longest and '
#            'shortest'},
#  {'author': 'Betsy Klein, Kate Sullivan and Geneva Sands, CNN',
#   'content': '(CNN)The Biden administration announced Friday it is terminating '
#              'a Trump-era agreement that it said discouraged sponsors of '
#              'unaccompanied migrant children, like parents or relatives, to '
#              'come forward … [+1548 chars]',
#   'date': '2021-03-12T17:23:06Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/biden-rescinds-trump-immigration-migrants-minors/index.html',
#   'title': 'Biden administration rescinds Trump-era immigration policy to '
#            'alleviate surge of unaccompanied minors'},
#  {'author': 'Ryan Prior, CNN',
#   'content': '(CNN)At the height of a luminous career in genetics, Ron Davis, '
#              'professor of biochemistry and genetics at Stanford University in '
#              'California, switched to researching a disease that many of his '
#              'colleag… [+8062 chars]',
#   'date': '2021-03-12T17:21:21Z',
#   'link': 'https://www.cnn.com/2021/03/12/health/ron-davis-covid-long-hauler-scn-wellness/index.html',
#   'title': "A Stanford scientist's quest to cure his son could help unravel "
#            'the mystery of Covid-19 long haulers'},
#  {'author': 'Kevin Liptak, CNN',
#   'content': '(CNN)President Joe Biden will take to the Rose Garden on Friday '
#              'for the first time as president, celebrating passage of his $1.9 '
#              'trillion Covid-19 relief measure as the kickoff to a weeks-long '
#              'sales … [+3365 chars]',
#   'date': '2021-03-12T17:19:45Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/joe-biden-covid-19-law-rose-garden/index.html',
#   'title': 'Biden returns once again to the Rose Garden for stimulus '
#            'celebration'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T17:18:34Z',
#   'link': 'https://www.cnn.com/videos/media/2021/03/12/bowling-alley-drone-video-orig-bdk.cnn',
#   'title': 'One-shot drone video of bowling alley mesmerizes internet'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T17:16:40Z',
#   'link': 'https://www.cnn.com/videos/us/2021/03/12/covid-vaccine-reunions-hugs-orig-jk.cnn',
#   'title': 'Tears and screams of joy as grandparents and kids reunite'},
#  {'author': 'Christine Romans, CNN',
#   'content': "(CNN)Looking at the stock market, you'd never know that a year "
#              'ago this week was the Coronavirus Crash.\r\n'
#              'In a matter of days, the S&amp;P 500 dropped 12% and into a bear '
#              'market. One-day point drops i… [+1987 chars]',
#   'date': '2021-03-12T17:14:29Z',
#   'link': 'https://www.cnn.com/2021/03/12/investing/stock-market-history-crashes/index.html',
#   'title': "History shows why it doesn't pay to bet against US stocks"},
#  {'author': 'By Mike Park',
#   'content': 'For way too long, anyone whos wanted to buy a beauty or skin '
#              'care product has had to make a choice between using a natural '
#              'remedy or one backed by science, as if you couldnt have one if '
#              'you wanted th… [+3622 chars]',
#   'date': '2021-03-12T17:14:21Z',
#   'link': 'https://www.cnn.com/2021/03/12/cnn-underscored/wow-skin-science/index.html',
#   'title': 'Put your beauty routine through a spring cleaning with WOW Skin '
#            'Science'},
#  {'author': 'By Mike Park',
#   'content': 'Even more welcome than when the local wings shop accidentally '
#              'sends you an extra dozen, March Madness is finally upon us. And '
#              'just as youve learned that you dont dive into a heap of spicy, '
#              'saucy wing… [+2390 chars]',
#   'date': '2021-03-12T17:12:42Z',
#   'link': 'https://www.cnn.com/2021/03/12/cnn-underscored/3000-discount-8k-qled-tv-samsung/index.html',
#   'title': 'Turn your living room couch into the best seats at every game with '
#            "Samsung's 2021 TVs"},
#  {'author': 'By Mike Park',
#   'content': 'Our worlds shrank so much in 2020 that you could be forgiven for '
#              'thinking that the favorite places youve ever been to from '
#              'wicker-laden, weathered East Coast beach houses to plush '
#              'riverside balconies… [+3544 chars]',
#   'date': '2021-03-12T17:12:16Z',
#   'link': 'https://www.cnn.com/2021/03/12/cnn-underscored/arhaus-outdoor-furniture/index.html',
#   'title': 'Turn your patio, porch or poolside into a restful retreat with '
#            'Arhaus'},
#  {'author': 'By Erica Lamberg',
#   'content': 'Many people believe that before buying a home, theyll need to '
#              'have 20% of the purchase price ready in cash to use as a down '
#              'payment. That can make the possibility of home ownership seem '
#              'overwhelming,… [+8283 chars]',
#   'date': '2021-03-12T17:02:03Z',
#   'link': 'https://www.cnn.com/2021/03/12/cnn-underscored/20-percent-down-payment-mortgage/index.html',
#   'title': 'Does it still make sense to put down 20% when buying a home?'},
#  {'author': 'Jennifer Agiesta, CNN Polling Director',
#   'content': None,
#   'date': '2021-03-12T17:00:25Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/cnn-poll-political-divisions/index.html',
#   'title': 'CNN Poll: Most Americans think election results could lead to '
#            'political violence in the coming years'},
#  {'author': 'By Marnie Hunter, CNN',
#   'content': '(CNN) The cheapest airline tickets are about to lose some of '
#              'their pandemic-era flexibility.\r\n'
#              'At the end of March, most major US carriers will drop waivers on '
#              'change fees for the lowest fare tier -- … [+4388 chars]',
#   'date': '2021-03-12T16:56:23Z',
#   'link': 'https://www.cnn.com/travel/article/airlines-basic-economy-change-fees/index.html',
#   'title': 'Window closing on fee-free changes to the cheapest airline '
#            'tickets'},
#  {'author': 'Anneken Tappe, CNN Business',
#   'content': None,
#   'date': '2021-03-12T16:52:45Z',
#   'link': 'https://www.cnn.com/2021/03/12/economy/march-consumer-sentiment-vaccines/index.html',
#   'title': 'Vaccines and stimulus boost US consumer sentiment'},
#  {'author': 'Chloe Melas, CNN',
#   'content': None,
#   'date': '2021-03-12T16:48:17Z',
#   'link': 'https://www.cnn.com/2021/03/12/entertainment/nick-jonas-spaceman-album-music-video-trnd/index.html',
#   'title': "Nick Jonas releases 'Spaceman' music video and album"},
#  {'author': 'Nimi Princewill, CNN',
#   'content': '(CNN)South Africans are calling for a state funeral be held in '
#              'honor of Zulu King Goodwill Zwelithini, the revered monarch of '
#              "the country's largest ethnic group, whose death was announced "
#              'Friday.\r\n'
#              'Ki… [+2772 chars]',
#   'date': '2021-03-12T16:34:35Z',
#   'link': 'https://www.cnn.com/2021/03/12/africa/zulu-king-zwelithini-dies-intl/index.html',
#   'title': "South Africa's Zulu King Goodwill Zwelithini dies at 72"},
#  {'author': 'Zayn Nabbi, CNN',
#   'content': '(CNN)Former British Cycling and Team Sky doctor Richard Freeman '
#              'has been found guilty of ordering testosterone "knowing or '
#              'believing it was to be administered to an athlete to improve '
#              'their athletic … [+1465 chars]',
#   'date': '2021-03-12T16:25:52Z',
#   'link': 'https://edition.cnn.com/2021/03/12/sport/dr-richard-freeman-british-cycling-spt-intl/index.html',
#   'title': 'Former British Cycling doctor found guilty of ordering banned '
#            'testosterone'},
#  {'author': 'Veronica Stracqualursi and Gregory Krieg, CNN',
#   'content': None,
#   'date': '2021-03-12T16:14:47Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/new-york-congress-cuomo-resignation/index.html',
#   'title': "Majority of New York congressional Democrats call for Gov. Cuomo's "
#            'resignation'},
#  {'author': 'Opinion by Amara Walker, CNN',
#   'content': 'Amara Walker is a correspondent and fill-in anchor for CNN. '
#              'Follow her on Instagram and Twitter. The views expressed in this '
#              'commentary belong to the author. View more opinion at CNN.\r\n'
#              ' (CNN)I know I… [+9468 chars]',
#   'date': '2021-03-12T16:13:11Z',
#   'link': 'https://www.cnn.com/2021/03/12/opinions/alexi-mccammond-apology-not-enough-anti-asian-walker/index.html',
#   'title': "Teen Vogue EIC Alexi McCammond's apology to Asians isn't enough"},
#  {'author': 'Nathaniel Meyersohn, CNN Business',
#   'content': None,
#   'date': '2021-03-12T16:00:52Z',
#   'link': 'https://www.cnn.com/2021/03/12/business/ulta-ceo-mary-dillon/index.html',
#   'title': 'Ulta CEO Mary Dillon is stepping down'},
#  {'author': 'Danielle Wiener-Bronner, CNN Business',
#   'content': 'New York (CNN Business)When the pandemic hit, something '
#              'astonishing happened in the cereal aisle: It cleared out. \r\n'
#              'Beloved brands like Grape-Nuts were suddenly out of stock. '
#              'Companies once desperate… [+4388 chars]',
#   'date': '2021-03-12T15:50:05Z',
#   'link': 'https://www.cnn.com/2021/03/12/business/cereal-sales-pandemic/index.html',
#   'title': 'The pandemic made these cereals cool again'},
#  {'author': 'Veronica Stracqualursi, CNN',
#   'content': None,
#   'date': '2021-03-12T15:34:31Z',
#   'link': 'https://www.cnn.com/2021/03/12/politics/ann-kirkpatrick-wont-seek-reelection/index.html',
#   'title': "Arizona Democrat Ann Kirkpatrick says she won't seek re-election "
#            'in 2022'},
#  {'author': 'Analysis by Max Foster and Lauren Said-Moorhouse, CNN',
#   'content': None,
#   'date': '2021-03-12T15:27:15Z',
#   'link': 'https://www.cnn.com/2021/03/12/uk/royal-news-newsletter-03-12-21-gbr-intl/index.html',
#   'title': "Harry and Meghan's seismic interview will be felt for generations"},
#  {'author': 'Analysis by Chris Cillizza, CNN Editor-at-large',
#   'content': 'THE POINT -- NOW ON YOUTUBE! \r\n'
#              'In each episode of his weekly YouTube show, Chris Cillizza will '
#              'delve a little deeper into the surreal world of politics. Click '
#              'to subscribe!',
#   'date': '2021-03-12T15:16:12Z',
#   'link': 'https://www.cnn.com/2021/03/12/_politics-zone-injection/covid-19-polling-coronavirus/index.html',
#   'title': 'The dark cloud hanging over all of this Covid-19 optimism'},
#  {'author': 'Marianne Garvey, CNN',
#   'content': None,
#   'date': '2021-03-12T15:07:49Z',
#   'link': 'https://www.cnn.com/2021/03/12/entertainment/jennifer-garner-ears-pierced/index.html',
#   'title': 'Jennifer Garner just got her ears pieced for the first time at 48'},
#  {'author': 'Marianne Garvey, CNN',
#   'content': None,
#   'date': '2021-03-12T15:04:10Z',
#   'link': 'https://www.cnn.com/2021/03/12/entertainment/greys-anatomy-premiere-death/index.html',
#   'title': "'Grey's Anatomy' mid-season premiere blindsides viewers with an "
#            'unexpected death'},
#  {'author': 'Rob Picheta, Amy Cassidy, Zahid Mahmood and Schams Elwazer, CNN',
#   'content': None,
#   'date': '2021-03-12T14:59:22Z',
#   'link': 'https://www.cnn.com/2021/03/12/uk/sarah-everard-body-identified-gbr-intl-scli/index.html',
#   'title': 'Police identify body of Sarah Everard, who went missing in London'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T14:53:12Z',
#   'link': 'https://www.cnn.com/videos/world/2021/03/11/anniversary-covid-19-global-restrictions-lockdowns-lon-orig-na.cnn',
#   'title': 'A year like no other. This is how the world survived lockdown'},
#  {'author': 'Analysis by Brian Lowry, CNN',
#   'content': '(CNN)After record-low viewing numbers for the Emmys and more '
#              'recently the Golden Globes, the Academy Awards unveil their '
#              'nominations on Monday staring down the barrel of a similar '
#              'scenario. And ironi… [+3775 chars]',
#   'date': '2021-03-12T14:30:05Z',
#   'link': 'https://www.cnn.com/2021/03/12/entertainment/oscar-nominations-preview/index.html',
#   'title': 'Oscar nominations: Once an outsider, Netflix might be the star in '
#            'a year of streaming'},
#  {'author': 'Review by Brian Lowry, CNN',
#   'content': '(CNN)Turns out Soleil Moon Frye -- TV\'s "Punky Brewster" -- '
#              'meticulously documented her formative years, recently wading '
#              'back through home movies, phone messages and photos and '
#              'assembling them into "… [+2630 chars]',
#   'date': '2021-03-12T14:28:28Z',
#   'link': 'https://www.cnn.com/2021/03/12/entertainment/kid-90-review/index.html',
#   'title': "In 'Kid 90,' Soleil Moon Frye opens a time capsule about being "
#            "young and famous in the '90s"},
#  {'author': 'Kristina Sgueglia, CNN',
#   'content': None,
#   'date': '2021-03-12T14:21:58Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/breonna-taylor-mother-tamika-palmer-still-no-justice/index.html',
#   'title': "Breonna Taylor's mother says her daughter's death and the lack of "
#            "justice is 'still unbelievable' a year later"},
#  {'author': 'Rob Picheta, CNN',
#   'content': 'London (CNN)The global rollout of the Oxford-AstraZeneca '
#              'Covid-19 vaccine has encountered another hurdle as a handful of '
#              'countries paused their use of the shot following reports it '
#              'could be linked to… [+7183 chars]',
#   'date': '2021-03-12T14:19:35Z',
#   'link': 'https://www.cnn.com/2021/03/12/europe/astrazeneca-vaccine-blood-clot-reports-denmark-reviews-intl/index.html',
#   'title': "AstraZeneca says 'no evidence' of blood clot risk from vaccine as "
#            'countries suspend its use'},
#  {'author': 'Brett Harman, CNN',
#   'content': None,
#   'date': '2021-03-12T14:13:44Z',
#   'link': 'https://www.cnn.com/2021/03/12/world/videos-of-the-week-mobile-march-12/index.html',
#   'title': 'Must-watch videos of the week'},
#  {'author': 'Kaya Yurieff, CNN Business',
#   'content': 'New York (CNN Business)On the audio-based app Clubhouse, people '
#              'are gathering in virtual rooms to make whale moaning noises or '
#              'to participate in silent meditation together. Hundreds of people '
#              'on the … [+5033 chars]',
#   'date': '2021-03-12T13:51:00Z',
#   'link': 'https://www.cnn.com/2021/03/12/tech/internet-boredom-pandemic/index.html',
#   'title': 'How a year of living almost exclusively online made the internet '
#            'weird again'},
#  {'author': 'By Eoin McSweeney, CNN',
#   'content': 'The lavender clogs can be customized with colorful shoe pins '
#              'called "Jibbitz charms" and come with white socks from Drew '
#              "House, Bieber's own clothing brand. Bieber and Crocs are "
#              '"grabbing the world b… [+1383 chars]',
#   'date': '2021-03-12T13:45:45Z',
#   'link': 'https://www.cnn.com/style/article/justin-bieber-crocs-scli-intl/index.html',
#   'title': 'Justin Bieber and Crocs are collaborating again, pairing clogs and '
#            'socks'},
#  {'author': 'Selina Wang and Charles Riley, CNN Business',
#   'content': None,
#   'date': '2021-03-12T13:40:09Z',
#   'link': 'https://www.cnn.com/2021/03/12/tech/ant-group-ceo-simon-hu/index.html',
#   'title': 'Simon Hu resigns as Ant Group CEO'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T13:38:11Z',
#   'link': 'https://www.cnn.com/videos/politics/2021/03/12/tim-ryan-relief-bill-joe-biden-deficit-newday-vpx.cnn',
#   'title': "Hear lawmaker's emotional plea to GOP members on Biden's relief "
#            'bill'},
#  {'author': 'Julia Horowitz, CNN Business',
#   'content': "A version of this story first appeared in CNN Business' Before "
#              'the Bell newsletter. Not a subscriber? You can sign up right '
#              'here.\r\n'
#              'London (CNN Business)Wall Street threw a party as President Joe '
#              'Bide… [+6061 chars]',
#   'date': '2021-03-12T13:29:18Z',
#   'link': 'https://www.cnn.com/2021/03/12/investing/premarket-stocks-trading/index.html',
#   'title': 'Why stocks could get a boost from $1,400 stimulus checks'},
#  {'author': 'Mallika Kallingal, CNN',
#   'content': None,
#   'date': '2021-03-12T13:23:42Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/nasa-perseverance-mars-navajo-scn-trnd/index.html',
#   'title': 'NASA is naming the rocks and soil on Mars in the Navajo language'},
#  {'author': None,
#   'content': None,
#   'date': '2021-03-12T13:18:39Z',
#   'link': 'https://www.cnn.com/videos/business/2021/03/12/coronavirus-broadway-jobs-new-york-city-quest-ron-ldn-vpx.cnn',
#   'title': 'Broadway was booming. Then Covid-19 took center stage'},
#  {'author': 'Christina Zdanowicz and Janine Mack, CNN\nVideo by Jeff Kopp, CNN',
#   'content': None,
#   'date': '2021-03-12T12:48:18Z',
#   'link': 'https://www.cnn.com/2021/03/12/us/grandparents-hug-grandkids-covid-vaccine-trnd/index.html',
#   'title': 'Grandparents are getting to hug their grandkids for the first time '
#            'after getting vaccinated'},
#  {'author': 'Toyin Owoseje, CNN',
#   'content': None,
#   'date': '2021-03-12T12:39:42Z',
#   'link': 'https://www.cnn.com/2021/03/12/entertainment/sharon-osbourne-apologizes-intl-scli-gbr/index.html',
#   'title': 'Sharon Osbourne apologizes for supporting Piers Morgan in Meghan '
#            'row'},
#  {'author': 'Opinion by Marianne Schnall',
#   'content': 'Marianne Schnall is a journalist and the author of "What Will It '
#              'Take to Make a Woman President? Conversations About Women, '
#              'Leadership and Power" and the founder of Feminist.com and What '
#              'Will It Take… [+35222 chars]',
#   'date': '2021-03-12T12:34:46Z',
#   'link': 'https://www.cnn.com/2021/03/12/opinions/one-year-of-covid-19-pandemic-womens-history-month-schnall/index.html',
#   'title': 'Women have taken a staggering Covid hit. Now they offer the best '
#            'hopes for the future'},
#  {'author': 'Ivana Kottasová, CNN',
#   'content': 'A version of this story appeared in the March 12 edition of '
#              "CNN's Coronavirus: Fact vs. Fiction newsletter. Sign up here to "
#              'receive the need-to-know headlines every weekday.\r\n'
#              ' (CNN)US President Joe B… [+7699 chars]',
#   'date': '2021-03-12T12:29:20Z',
#   'link': 'https://www.cnn.com/2021/03/12/world/coronavirus-newsletter-03-12-21-int/index.html',
#   'title': "'I need every American to do their part,' says Biden, targeting "
#            'the end of the pandemic'}]

# %% [markdown]
# ### Save as json file

# %%
# Save articles_json as articles.json
articles_json = json.dumps(articles_json, indent = 4)
with open("articles.json", "w") as outfile:
    outfile.write(articles_json)
